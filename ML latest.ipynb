# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models #add models to the list
from torchvision.utils import make_grid
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

from torch import nn, optim
from torchvision.models import resnet18
from nfnets import WSConv2d, WSConvTranspose2d, ScaledStdConv2d
from nfnets.agc import AGC #Needs testing

# %%
train_transform = transforms.Compose([
        #transforms.Resize(224),             # resize shortest side to 224 pixels
        #transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        #transforms.Normalize([0.485, 0.456, 0.406],
        #                    [0.229, 0.224, 0.225])
    ])

test_transform = transforms.Compose([
        #transforms.Resize(224),
        #transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %%
root = '../data/fusion/AF_c-15/'

train_data = datasets.ImageFolder(os.path.join(root, 'train'),transform=train_transform)
test_data = datasets.ImageFolder(os.path.join(root, 'test'),transform=test_transform)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-99628c30b107> in <module>
# ----> 1 train_data[0].size
#
# AttributeError: 'tuple' object has no attribute 'size'

# %%
torch.manual_seed(42)
train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=True)

class_names = test_data.classes

print(class_names)
print(f'Training images available: {len(train_data)}')
print(f'Testing images available:  {len(test_data)}')
# Grab the first batch of 10 images
for images,labels in test_loader: 
    break
# Out:
# ['16', '32', '8']
# Training images available: 1050
# Testing images available:  450

# %%
conv1 = nn.Conv2d(3,6,3,1)
conv2 = nn.Conv2d(6,16,3,1)
for i, (X_train, y_train) in enumerate(train_data):
    break
cc,vv,zz =X_train.shape
cc
vv
zz
x = X_train.view(1,3,vv, zz)
x = F.relu(conv1(x))
x= F.max_pool2d(x,2,2)
x = F.relu(conv2(x))
x = F.max_pool2d(x,2,2)
xxx, ccc,vvv,zzz= x.shape

# %%
cc
vv
zz
# Out:
# 711

# %%
cc
# Out:
# 3

# %%
vv
# Out:
# 1298

# %%
zz
# Out:
# 711

# %%
# Print the labels
print('Label:', labels.numpy())
print('Class:', *np.array([class_names[i] for i in labels]))

im = make_grid(images, nrow=5)  # the default nrow is 8

# Inverse normalize the images
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)
im_inv = inv_normalize(im)

# Print the images
plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im_inv.numpy(), (1, 2, 0)));
import timm
from pprint import pprint
model_names = timm.list_models(pretrained=True)
#pprint(model_names)
# Out:
# Label: [2 1 2 2 2 2 2 1 0 1]
# Class: 8 32 8 8 8 8 8 32 16 32

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 3, 1)# 3,6,3,1 one color or three
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(16*vvv*zzz, 120) #16*58*211
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 3)  # 3 is class outputs 

    def forward(self, X):
        X = F.relu(self.conv1(X))
        print("conv1")
        print(X.size())
        X = F.max_pool2d(X, 2, 2)
        print("pool")
        print(X.size())
        X = F.relu(self.conv2(X))
        print("conv2")
        print(X.size())
        X = F.max_pool2d(X, 2, 2)
        print("pool")
        print(X.size())
        X = X.view(-1, 16*vvv*zzz) #two 16*105*118 #one 16*152*185
        X = F.relu(self.fc1(X))
        print(X.size())
        X = F.relu(self.fc2(X))
        print(X.size())
        X = self.fc3(X)
        print(X.size())
        return F.log_softmax(X, dim=1)

torch.manual_seed(101)
model = ConvolutionalNetwork()
#model = timm.create_model('resnet50' , pretrained= True ,num_classes = 3)
#model = timm.create_model('efficientnet_b4' , pretrained= True ,num_classes = 3)
#model = timm.create_model('mobilenetv3_large_100' , pretrained= True ,num_classes = 3)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
import time
start_time = time.time()

epochs = 1


train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        
        b+=1

        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum() #true 1/false 0
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print interim results
        if b%10 == 0: #600
            '''
            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/800]  loss: {loss.item():10.8f}  \
            accuracy: {trn_corr.item()*100/(10*b):7.3f}%')
            '''
            print(f"EPOCH: {i} BATCH: {b} LOSS: {loss.item()}")
            
    train_losses.append(loss)
    train_correct.append(trn_corr)

    # Run the Testing batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(test_loader):

            # Apply the model
            y_val = model(X_test)

            # Tally the number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            tst_corr += (predicted == y_test).sum()

    loss = criterion(y_val, y_test)
    test_losses.append(loss)
    test_correct.append(tst_corr)
# print the time elapsed
print(f'\nDuration: {time.time() - start_time:.0f} seconds') 

print(f'Test accuracy: {test_correct[-1].item()*100/450:.3f}%')
# Out:
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 10 LOSS: 1.4651685953140259
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 20 LOSS: 1.1915802955627441
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 30 LOSS: 1.0317089557647705
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 40 LOSS: 1.117583155632019
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 50 LOSS: 1.101111650466919
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 60 LOSS: 1.0576608180999756
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 70 LOSS: 1.2007967233657837
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 80 LOSS: 1.022841215133667
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 90 LOSS: 1.1206728219985962
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# EPOCH: 0 BATCH: 100 LOSS: 1.2174779176712036
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
# conv1
# torch.Size([10, 6, 1296, 709])
# pool
# torch.Size([10, 6, 648, 354])
# conv2
# torch.Size([10, 16, 646, 352])
# pool
# torch.Size([10, 16, 323, 176])
# torch.Size([10, 120])
# torch.Size([10, 84])
# torch.Size([10, 3])
#
# Duration: 446 seconds
# Test accuracy: 37.556%

# %%
compare the three, charts  
const + eye 
AF not good indiviully.
